# %% [markdown]
# # Analyze Single Cell Fluorescence Intensity from embryo sections
#
# This code was used to analyze BRE activity within single neural crest nuclei from section images.
#
# Required inputs for this script:
#
# 1. Folder containing csv file for each image documenting the area, mean, intden, and raw intden for individual cell regions of interest (ROIs) masked and measured in Fiji
#
# Script prepared by Mike Piacentino, March 2021

# %% [markdown]
# ### Import Packages

# %%
# Import data handling and analysis packages
import os
import pandas as pd
import glob
from scipy import stats
import scikit_posthocs

# Import plotting packages
import iqplot
import bokeh.io
from bokeh.io import output_file, show
from bokeh.layouts import column, row
bokeh.io.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ### Import Data
# First from 01/29/2021 imaging - collected z-stacks but analyzed a single optical slice in Fiji. The 'Label' reflects this, and is different from the next experiment.

# %%
# Identify path to raw measurements and initialize dataframe
path = os.path.abspath('')+'/source_data/csv_20210129/'
full_df_1 = pd.DataFrame()
list_ = []

# Loop through files, parse experiment information from names and labels, and concatenate into single dataframe
for file_ in glob.glob(path + "/*.csv"):
    df = pd.read_csv(file_)

    # Determine Image name from file name
    df['Image'] = os.path.splitext(os.path.basename(file_))[0]
    # Split values in ROI label
    df['del1'], df['ROI'], df['del2'], df['Channel'], df['del3'] = zip(*df['Label'].map(lambda x: x.split(':')))
    # Split values in Image name column
    (df['ExptDate'], df['Electroporation'], df['Stains'], df['Embryo'], 
        df['Somites'], df['Section'], df['Population']) = zip(*df['Image'].map(lambda x: x.split('_')))
    # Sort columns in dataframes 
    df = df.filter(['ExptDate','Electroporation','Stains','Embryo','Somites','Section','Population','Channel','ROI',
                    'Area','Mean','IntDen','RawIntDen'], axis=1)
    # Replace channel names
    df.replace(to_replace=['1/3 z', '2/3 z', '3/3 z'], value=['Pax7', 'RFP', 'BRE'], inplace=True)
    # Append list to populate output dataframe
    list_.append(df)

# Compile dataframe
full_df_1 = pd.concat(list_)
# Define a unique identifier to each section
full_df_1['SecID'] = (full_df_1['ExptDate'] + '_' + full_df_1['Embryo'] 
                      + '_' + full_df_1['Somites'] + '_' + full_df_1['Section'])

full_df_1.head(3)
# Out:
#    ExptDate Electroporation           Stains Embryo Somites Section  \
# 0  20210121   BRE;H2Bd2EGFP  Pax7;RFP;d2EGFP   Emb6    11ss    sec3
# 1  20210121   BRE;H2Bd2EGFP  Pax7;RFP;d2EGFP   Emb6    11ss    sec3
# 2  20210121   BRE;H2Bd2EGFP  Pax7;RFP;d2EGFP   Emb6    11ss    sec3
#
#   Population Channel        ROI      Area     Mean      IntDen   RawIntDen  \
# 0        pNC    Pax7        pNC  5214.992  167.979  876008.253  17000296.0
# 1        pNC    Pax7  0001-0505    40.605  322.387   13090.479    254041.0
# 2        pNC    Pax7  0002-0494    19.684  435.673    8575.817    166427.0
#
#                      SecID
# 0  20210121_Emb6_11ss_sec3
# 1  20210121_Emb6_11ss_sec3
# 2  20210121_Emb6_11ss_sec3

# %% [markdown]
# ### Import Data
# First from 01/29/2021 imaging - collected z-stacks but analyzed a single optical slice. The 'Label' reflects this, and is different from the next experiment.

# %%
# Identify path to raw measurements and initialize dataframe
path = os.path.abspath('')+'/source_data/csv_20210216/'
full_df_2 = pd.DataFrame()
list_ = []

# Loop through files, parse experiment information from names and labels, and concatenate into single dataframe
for file_ in glob.glob(path + "/*.csv"):
    df = pd.read_csv(file_)

    # Determine Image name from file name
    df['Image'] = os.path.splitext(os.path.basename(file_))[0]
    # Split values in ROI label
    df['temp1'], df['ROI'], df['temp2'], df['temp3'] = zip(*df['Label'].map(lambda x: x.split(':')))
    df['Channel'], df['temp5'] = zip(*df['temp3'].map(lambda x: x.split(' - ')))
    # Split values in Image name column
    (df['ExptDate'], df['Electroporation'], df['Stains'], df['Embryo'], 
        df['Somites'], df['Section'], df['Population']) = zip(*df['Image'].map(lambda x: x.split('_')))
    # Sort columns in dataframes 
    df = df.filter(['ExptDate','Electroporation','Stains','Embryo','Somites','Section','Population','Channel','ROI',
                    'Area','Mean','IntDen','RawIntDen'], axis=1)
    # Replace channel names
    df.replace(to_replace=['1/4', '2/4', '3/4'], value=['Pax7', 'RFP', 'BRE'], inplace=True)
    # Append list to populate output dataframe
    list_.append(df)

# Compile dataframe
full_df_2 = pd.concat(list_)
# Define a unique identifier to each section
full_df_2['SecID'] = (full_df_2['ExptDate'] + '_' + full_df_2['Embryo'] 
                      + '_' + full_df_2['Somites'] + '_' + full_df_2['Section'])

full_df_2.head(6)
# Out:
#    ExptDate Electroporation           Stains Embryo Somites Section  \
# 0  20210210   BRE;H2Bd2EGFP  Pax7;RFP;d2EGFP   Emb9     8ss    sec1
# 1  20210210   BRE;H2Bd2EGFP  Pax7;RFP;d2EGFP   Emb9     8ss    sec1
# 2  20210210   BRE;H2Bd2EGFP  Pax7;RFP;d2EGFP   Emb9     8ss    sec1
# 0  20210210   BRE;H2Bd2EGFP  Pax7;RFP;d2EGFP   Emb6     8ss    sec5
# 1  20210210   BRE;H2Bd2EGFP  Pax7;RFP;d2EGFP   Emb6     8ss    sec5
# 2  20210210   BRE;H2Bd2EGFP  Pax7;RFP;d2EGFP   Emb6     8ss    sec5
#
#    Population Channel         ROI      Area     Mean      IntDen   RawIntDen  \
# 0  background    Pax7  background    44.521   10.713     476.952      9256.0
# 1  background     RFP  background    44.521    6.605     294.076      5707.0
# 2  background     BRE  background    44.521    6.660     296.498      5754.0
# 0         pNC    Pax7         pNC  3052.939  285.410  871338.695  16909676.0
# 1         pNC    Pax7   0001-0627    19.323  491.739    9502.051    184402.0
# 2         pNC    Pax7   0002-0644    23.909  442.955   10590.807    205531.0
#
#                     SecID
# 0  20210210_Emb9_8ss_sec1
# 1  20210210_Emb9_8ss_sec1
# 2  20210210_Emb9_8ss_sec1
# 0  20210210_Emb6_8ss_sec5
# 1  20210210_Emb6_8ss_sec5
# 2  20210210_Emb6_8ss_sec5

# %% [markdown]
# ### Merge these datasets into one df

# %%
full_df = pd.concat([full_df_1, full_df_2])
full_df.head()
# Out:
#    ExptDate Electroporation           Stains Embryo Somites Section  \
# 0  20210121   BRE;H2Bd2EGFP  Pax7;RFP;d2EGFP   Emb6    11ss    sec3
# 1  20210121   BRE;H2Bd2EGFP  Pax7;RFP;d2EGFP   Emb6    11ss    sec3
# 2  20210121   BRE;H2Bd2EGFP  Pax7;RFP;d2EGFP   Emb6    11ss    sec3
# 3  20210121   BRE;H2Bd2EGFP  Pax7;RFP;d2EGFP   Emb6    11ss    sec3
# 4  20210121   BRE;H2Bd2EGFP  Pax7;RFP;d2EGFP   Emb6    11ss    sec3
#
#   Population Channel        ROI      Area     Mean      IntDen   RawIntDen  \
# 0        pNC    Pax7        pNC  5214.992  167.979  876008.253  17000296.0
# 1        pNC    Pax7  0001-0505    40.605  322.387   13090.479    254041.0
# 2        pNC    Pax7  0002-0494    19.684  435.673    8575.817    166427.0
# 3        pNC    Pax7  0003-0508    26.125  398.142   10401.541    201858.0
# 4        pNC    Pax7  0004-0516    23.806  258.158    6145.812    119269.0
#
#                      SecID
# 0  20210121_Emb6_11ss_sec3
# 1  20210121_Emb6_11ss_sec3
# 2  20210121_Emb6_11ss_sec3
# 3  20210121_Emb6_11ss_sec3
# 4  20210121_Emb6_11ss_sec3

# %% [markdown]
# ### Calculate Corrected Total Cellular Fluorescence (CTCF) for each ROI
#
# This will determine the fluorescence in each ROI (expression level), corrected for size and background intensity in the image
#
# <center>$CTCF = IntDen_{ROI} - (Area_{ROI} * Mean_{background})$</center>

# %%
# Determine channels and sections in dataframe to prepare loops
channels_list = full_df['Channel'].unique().tolist()
sec_list = full_df['SecID'].unique().tolist()

# Initialize output dataframe
df_ctcf = pd.DataFrame()
output_list = []

# Loop through sections...
for sec in sec_list:
    df_sec = pd.DataFrame(full_df[full_df['SecID'] == sec])
    
    # ... then loop through channels
    for ch in channels_list:
        df_ch = pd.DataFrame(df_sec[df_sec['Channel'] == ch])
        # Save out mean background intensity
        background_mean = df_ch.loc[df_ch['ROI'] == 'background']['Mean']
        
        # Make an ROI list, remove the 'background' ROI, then loop through ROIs
        roi_list = df_ch['ROI'].unique().tolist()
        roi_list.remove('background')
        for roi in roi_list:
            df_roi = pd.DataFrame(df_ch[df_ch['ROI'] == roi])
            # Calculate CTCF
            df_roi['CTCF'] = float(df_roi['IntDen']) - (float(df_roi['Area']) * float(background_mean))
            # Append list to populate output dataframe
            output_list.append(df_roi)

# Compile dataframe
df_ctcf = pd.concat(output_list)

df_ctcf.head(3)
# Out:
#    ExptDate Electroporation           Stains Embryo Somites Section  \
# 0  20210121   BRE;H2Bd2EGFP  Pax7;RFP;d2EGFP   Emb6    11ss    sec3
# 1  20210121   BRE;H2Bd2EGFP  Pax7;RFP;d2EGFP   Emb6    11ss    sec3
# 2  20210121   BRE;H2Bd2EGFP  Pax7;RFP;d2EGFP   Emb6    11ss    sec3
#
#   Population Channel        ROI      Area     Mean      IntDen   RawIntDen  \
# 0        pNC    Pax7        pNC  5214.992  167.979  876008.253  17000296.0
# 1        pNC    Pax7  0001-0505    40.605  322.387   13090.479    254041.0
# 2        pNC    Pax7  0002-0494    19.684  435.673    8575.817    166427.0
#
#                      SecID           CTCF
# 0  20210121_Emb6_11ss_sec3  821621.101432
# 1  20210121_Emb6_11ss_sec3   12667.009455
# 2  20210121_Emb6_11ss_sec3    8370.532564

# %% [markdown]
# ### Now determine the ratio of BRE CTCF/RFP CTCF to normalize BRE intensity to an electroporation control

# %%
# Determine sections in dataframe to prepare loop, and initialize output dataframe
sec_list = df_ctcf['SecID'].unique().tolist()
norm_output = []
df_norm_bre = pd.DataFrame()

# Loop through sections...
for sec in sec_list:
    df_sec = pd.DataFrame(df_ctcf[df_ctcf['SecID'] == sec])

    # Make an ROI list, then loop through ROIs
    roi_list = df_sec['ROI'].unique().tolist()
    for roi in roi_list:
        # Extract dataframe specific to ROI
        roi_df = df_sec.loc[df_sec['ROI'] == roi]
        # Record CTCF values for BRE and RFP within this ROI
        bre = float(roi_df.loc[roi_df['Channel']=='BRE']['CTCF'])
        rfp = float(roi_df.loc[roi_df['Channel']=='RFP']['CTCF'])
        # Extract just the BRE row
        roi_bre_df = roi_df.loc[roi_df['Channel']=='BRE'].reset_index().drop(['index'], axis=1)
        # Add Normalized CTCF to the BRE row
        roi_bre_df.loc[0, 'NormCTCF'] = bre/rfp
        # Append list to populate output dataframe
        norm_output.append(roi_bre_df)

# Compile dataframe
df_norm_bre = pd.concat(norm_output)

df_norm_bre.head()
# Out:
#    ExptDate Electroporation           Stains Embryo Somites Section  \
# 0  20210121   BRE;H2Bd2EGFP  Pax7;RFP;d2EGFP   Emb6    11ss    sec3
# 0  20210121   BRE;H2Bd2EGFP  Pax7;RFP;d2EGFP   Emb6    11ss    sec3
# 0  20210121   BRE;H2Bd2EGFP  Pax7;RFP;d2EGFP   Emb6    11ss    sec3
# 0  20210121   BRE;H2Bd2EGFP  Pax7;RFP;d2EGFP   Emb6    11ss    sec3
# 0  20210121   BRE;H2Bd2EGFP  Pax7;RFP;d2EGFP   Emb6    11ss    sec3
#
#   Population Channel        ROI      Area     Mean      IntDen   RawIntDen  \
# 0        pNC     BRE        pNC  5214.992  117.818  614417.419  11923721.0
# 0        pNC     BRE  0001-0505    40.605  268.901   10918.686    211894.0
# 0        pNC     BRE  0002-0494    19.684  408.516    8041.255    156053.0
# 0        pNC     BRE  0003-0508    26.125   22.329     583.360     11321.0
# 0        pNC     BRE  0004-0516    23.806  486.710   11586.811    224860.0
#
#                      SecID           CTCF  NormCTCF
# 0  20210121_Emb6_11ss_sec3  577364.900840  1.566489
# 0  20210121_Emb6_11ss_sec3   10630.187475  1.848860
# 0  20210121_Emb6_11ss_sec3    7901.400180  0.964088
# 0  20210121_Emb6_11ss_sec3     397.741875  0.577789
# 0  20210121_Emb6_11ss_sec3   11417.669370  2.798568

# %% [markdown]
# ## Exploratory Plotting in ECDF and Stripbox Formats

# %%
# Define data subset to plot
data = df_norm_bre[~df_norm_bre['ROI'].isin(['pNC', 'mNC', 'background'])]  #Selects all single-cell ROIs

# Build ECDF plot
ecdf = iqplot.ecdf(
                    # Data to plot
                        data=data,
                        q='NormCTCF', q_axis='x',
                        cats=['Somites'],

                    # Plot details
                        style='staircase',
                        conf_int=True, ptiles=[2.5, 97.5],        #95% CIs, use [16,84] for SEM (68% CI)
                        x_axis_type='log',
                        frame_width=500, frame_height=400,

                    # Plot Customizations
                        order=['3ss','6ss','7ss','8ss','9ss','10ss','11ss'],
                        palette=['#c6dbef','#9ecae1','#6baed6','#4292c6','#2171b5','#08519c','#08306b'],
                        title='Norm. BRE CTCF',
                        y_axis_label='Empirical Cumulative Distribution Frequency',
                        x_axis_label='Log Normalized BRE activity',
    
)
ecdf.axis.axis_label_text_font_size = '14px'
ecdf.axis.major_label_text_font_size = '14px'
ecdf.axis.axis_label_text_font_style = 'normal'

# Build Stripbox plot
stripbox = iqplot.stripbox(
                    # Data to plot
                        data=data,
                        q='NormCTCF', q_axis='y',
                        cats=['Somites'], 

                    # Plot details
                        jitter=True, jitter_kwargs=dict(width=0.3),
                        marker_kwargs=dict(alpha=0.2),
                        box_kwargs=dict(line_color='black', line_width=1.5),
                        whisker_kwargs=dict(line_color='black', line_width=1.5),
                        median_kwargs=dict(line_color='black', line_width=2),
                        top_level='box',
                        y_axis_type='log',
                        frame_width=500, frame_height=400,

                    # Plot customizations
                        order=['3ss','6ss','7ss','8ss','9ss','10ss','11ss'],
                        color_column='Population',
                        title='Norm. BRE CTCF',
                        y_axis_label='Log Normalized BRE Activity',
                        x_axis_label='Embryo stage',
                        show_legend=True,
)
stripbox.axis.axis_label_text_font_size = '14px'
stripbox.axis.major_label_text_font_size = '14px'
stripbox.axis.axis_label_text_font_style = 'normal'
stripbox.legend.location = 'bottom_center'

# Display plots
show(row(ecdf, stripbox))
# Out:
#   <div class="bk-root" id="00780d4a-cddd-452f-ab2c-20d5887b2e5a" data-root-id="2193"></div>

# %% [markdown]
# # Statistical Analysis

# %% [markdown]
# #### One-Way ANOVA with Tukey's Post-hoc for Multiple Comparisons

# %%
# Determine samples to compare
samples_list = data['Somites'].unique().tolist()
samples_list
# Out:
# ['11ss', '3ss', '10ss', '6ss', '8ss', '7ss', '9ss']

# %%
### One-way ANOVA

# Define metric to test
metric = 'NormCTCF'
sample_column = 'Somites'
# Define samples to compare
sample1 = '3ss'
sample2 = '6ss'
sample3 = '7ss'
sample4 = '8ss'
sample5 = '9ss'
sample6 = '10ss'
sample6 = '11ss'
# ... can add more

# Run One-way ANOVA test
anova_result = stats.f_oneway(
                data.loc[data[sample_column]==sample1][metric]
               ,data.loc[data[sample_column]==sample2][metric]
               ,data.loc[data[sample_column]==sample3][metric]
               ,data.loc[data[sample_column]==sample4][metric]
               ,data.loc[data[sample_column]==sample5][metric]
               ,data.loc[data[sample_column]==sample6][metric]
    )

# Tukey's post-hoc for multiple comparisons
mult_compar = scikit_posthocs.posthoc_tukey(data, val_col=metric, group_col=sample_column).round(6)

# Display test results
print('One-way Anova test results: \n\t\t\t statistic=' + str(anova_result[0]) + 
    '\n\t\t\t p-value=' + str(anova_result[1]))
print("\nTukey's post-hoc multiple comparison result: \n" + str(mult_compar) +'\n')
# mult_compar.to_csv("Results of Tukey's Posthoc.csv")

# Get number of cells within this test
for sample in data[sample_column].unique().tolist():
    temp_df = data.loc[data[sample_column] == sample]
    print('n = ' + str(len(temp_df)) + ' cells in the ' + str(sample) + ' dataset.')
# Out:
# One-way Anova test results:
# 			 statistic=28.049636416786054
# 			 p-value=7.917812110385145e-28
#
# Tukey's post-hoc multiple comparison result:
#           11ss       3ss      10ss       6ss    8ss       7ss       9ss
# 11ss  1.000000  0.001000  0.900000  0.007202  0.001  0.900000  0.007112
# 3ss   0.001000  1.000000  0.001000  0.900000  0.001  0.007079  0.001000
# 10ss  0.900000  0.001000  1.000000  0.003630  0.001  0.900000  0.014268
# 6ss   0.007202  0.900000  0.003630  1.000000  0.001  0.041332  0.001000
# 8ss   0.001000  0.001000  0.001000  0.001000  1.000  0.001000  0.900000
# 7ss   0.900000  0.007079  0.900000  0.041332  0.001  1.000000  0.016831
# 9ss   0.007112  0.001000  0.014268  0.001000  0.900  0.016831  1.000000
#
# n = 1097 cells in the 11ss dataset.
# n = 916 cells in the 3ss dataset.
# n = 942 cells in the 10ss dataset.
# n = 152 cells in the 6ss dataset.
# n = 277 cells in the 8ss dataset.
# n = 305 cells in the 7ss dataset.
# n = 93 cells in the 9ss dataset.
